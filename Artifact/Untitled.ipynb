# %%
import pandas as pd

# %%
df = pd.read_csv('highway_101.csv')

# %%
df1 = pd.read_csv('vehicle-trajectory-data/0750am-0805am/vehicle_100.csv')
df1
# Out:
#      Unnamed: 0  Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X  \
# 0         27232         100       228           449  1118847001700   51.598
# 1         27233         100       229           449  1118847001800   51.576
# 2         27234         100       230           449  1118847001900   51.552
# 3         27235         100       231           449  1118847002000   51.529
# 4         27236         100       232           449  1118847002100   51.507
# ..          ...         ...       ...           ...            ...      ...
# 444       27676         100       672           449  1118847046100   55.989
# 445       27677         100       673           449  1118847046200   56.147
# 446       27678         100       674           449  1118847046300   56.208
# 447       27679         100       675           449  1118847046400   56.203
# 448       27680         100       676           449  1118847046500   56.199
#
# ...

# %%
df1['Lane_ID'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 444    5
# 445    5
# 446    5
# 447    5
# 448    5
# Name: Lane_ID, Length: 449, dtype: int64>

# %%
df2 = pd.read_csv('lane_controllers/lane_controller0.csv')
df2
# Out:
#     Unnamed: 0         Y
# 0     0.000000  0.029552
# 1     0.202020  0.064730
# 2     0.404040  0.089484
# 3     0.606061  0.099828
# 4     0.808081  0.094095
# ..         ...       ...
# 95   19.191919  0.031351
# 96   19.393939  0.010179
# 97   19.595960 -0.012281
# 98   19.797980 -0.032419
# 99   20.000000 -0.047052
#
# [100 rows x 2 columns]
